# %% [markdown]
# <a href="https://colab.research.google.com/github/WannaGetDSJobInSanFrancisco/colab_frcnn/blob/main/Faster_R_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Faster R-CNNColab実装！
# コードにちょくちょく至らぬところはあると思いますがご容赦願います

# %% [markdown]
# ## For stand-alone usage without files in MyDrive
# - clone repository / extract data in current directory

# %%
# !git clone https://github.com/Ryunosuke-Ikeda/colab_frcnn
# Out:
# Cloning into 'colab_frcnn'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 48 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (48/48), done.

# %%
# %mkdir colab_frcnn-main
# !unzip colab_frcnn/smallbdd.zip -d colab_frcnn-main
# Out:
# Archive:  colab_frcnn/smallbdd.zip
#    creating: colab_frcnn-main/smallbdd/img/
#   inflating: colab_frcnn-main/smallbdd/img/0000f77c-6257be58.jpg
#   inflating: colab_frcnn-main/smallbdd/img/0000f77c-62c2a288.jpg
#   inflating: colab_frcnn-main/smallbdd/img/0000f77c-cb820c98.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000d35d3-41990aa4.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000d4f89-3bcbe37a.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000e0252-8523a4a9.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000f157f-30b30f5e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000f157f-37797ff9.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000f157f-dab3a407.jpg
#   inflating: colab_frcnn-main/smallbdd/img/000f8d37-d4c09a0f.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a04f65-8c891f94.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a04f65-af2ab984.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a0f008-3c67908e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a0f008-a315437f.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a1176f-0652080e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a1176f-5121b501.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a2e3ca-5c856cde.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a2e3ca-62992459.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a2f5b6-d4217a96.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a395fe-d60c0b47.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a820ef-2b98dcf5(1).jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a820ef-2b98dcf5.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a820ef-98a12e22(1).jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a820ef-98a12e22.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a820ef-d655700e(1).jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a820ef-d655700e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a9cd6b-b39be004(1).jpg
#   inflating: colab_frcnn-main/smallbdd/img/00a9cd6b-b39be004.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00abd8a7-ecd6fc56.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00abf44e-04004ca0.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00abf44e-421f6ed7.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ac3256-0f8e2cda.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ad8a92-c4851839.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00adbb3f-7757d4ea.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00afa5b2-c14a542f.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00afa6b9-4efe0141.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b04b12-a7d7eb85.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b04b30-2e874876.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b04b30-501822fa.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b1dfed-a89dbe2b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b4c5fc-8fcf3628.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b56f41-e0e5d918.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00b93c6e-6298aa25.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00be7020-457a6db4.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00beeb02-50440dcd.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00beeb02-ba0790aa.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c12bd0-bb46e479.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c17a92-d4803287.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c29c52-f9524f1e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c41a61-4ba25ad4.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c497ae-595d361b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c4c672-26d36ad8.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c50078-6298b9c1.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00c87627-b7f6f46c.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ca8821-17667a58.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ca8821-db8033d5.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cb28b9-08a22af7.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ccf2e8-59a6bfc9.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ccf2e8-ac055be6.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ccf2e8-f8c69860.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ce6f6d-50bbee62.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ce8219-12c6d905.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ce8219-d0b5582e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ce95b0-84be34a3.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cea101-06f21d5e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cea101-293a30b5.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cee0e0-5e25daa7.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cef86b-204ea619.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cef86b-d8d105b9.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cf8e3d-3d27efb0.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cf8e3d-4683d983.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cf8e3d-773de15e.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00cf8e3d-a7b4978c.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d0f034-6d666f7b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d15d58-9197cde5.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d18b13-52d3e4c4.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d1bafa-1b47b41c.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d1bafa-6701fcd9.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d4b6b7-7d0a60bf.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d4b6b7-a0b1a3e0.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d5edb9-f0077df3.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d7268f-fd4487be.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d77344-9fe25620.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d79c0a-23bea078.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d79c0a-a2b85ca4.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d84b1d-21e6fe01.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d8944b-e157478b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d8d95a-47d98291.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d8d95a-74aa476a.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d9e313-038310a2.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d9e313-7d75bb18.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00d9e313-926b6698.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00db9030-5102ed41.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00dc5030-237e7f71.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00de601c-858a8a8d.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00de601c-cfa2404b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e02d60-54df99d1.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e100a8-9c852617.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e100a8-a5e1ece9.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e11419-e4eeba84.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e42886-b826e91d.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e42886-bd5ed543.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e49ed1-9d41220c.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e4cae5-c0582574.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e5e793-22614772.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e5e793-f94de032.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e782b9-5fe9bffe.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e81dcc-b1dd9e7b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00e8c106-e197c4b1.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00eb41b2-6bbff2ca.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ecf963-bea6bf0f.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ed2e85-82bdd22b.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00ed2e85-95394dfd.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00edfec7-4d92adef.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f0dd0f-1adbde75.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f0dd0f-5e9c9557.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f28fce-a799f8a1.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f2b0d5-c84860fe.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f42f6b-5a20a4d2.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f42f6b-699a498c.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f42f6b-b1ca1f6c.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f7eac8-5193d600.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f89335-2ef7949d.jpg
#   inflating: colab_frcnn-main/smallbdd/img/00f8f875-bad0295f.jpg
#    creating: colab_frcnn-main/smallbdd/test/
#   inflating: colab_frcnn-main/smallbdd/test/cb7c8bb9-bc2d62ba.jpg
#   inflating: colab_frcnn-main/smallbdd/test/cd4ce4e5-d0968ec0.jpg
#    creating: colab_frcnn-main/smallbdd/xml/
#   inflating: colab_frcnn-main/smallbdd/xml/0000f77c-6257be58.xml
#   inflating: colab_frcnn-main/smallbdd/xml/0000f77c-62c2a288.xml
#   inflating: colab_frcnn-main/smallbdd/xml/0000f77c-cb820c98.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000d35d3-41990aa4.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000d4f89-3bcbe37a.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000e0252-8523a4a9.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000f157f-30b30f5e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000f157f-37797ff9.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000f157f-dab3a407.xml
#   inflating: colab_frcnn-main/smallbdd/xml/000f8d37-d4c09a0f.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a04f65-8c891f94.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a04f65-af2ab984.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a0f008-3c67908e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a0f008-a315437f.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a1176f-0652080e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a1176f-5121b501.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a2e3ca-5c856cde.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a2e3ca-62992459.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a2f5b6-d4217a96.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a395fe-d60c0b47.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a820ef-2b98dcf5.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a820ef-98a12e22.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a820ef-d655700e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00a9cd6b-b39be004.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00abd8a7-ecd6fc56.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00abf44e-04004ca0.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00abf44e-421f6ed7.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ac3256-0f8e2cda.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ad8a92-c4851839.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00adbb3f-7757d4ea.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00afa5b2-c14a542f.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00afa6b9-4efe0141.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b04b12-a7d7eb85.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b04b30-2e874876.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b04b30-501822fa.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b1dfed-a89dbe2b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b4c5fc-8fcf3628.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b56f41-e0e5d918.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00b93c6e-6298aa25.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00be7020-457a6db4.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00beeb02-50440dcd.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00beeb02-ba0790aa.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c12bd0-bb46e479.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c17a92-d4803287.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c29c52-f9524f1e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c41a61-4ba25ad4.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c497ae-595d361b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c4c672-26d36ad8.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c50078-6298b9c1.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00c87627-b7f6f46c.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ca8821-17667a58.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ca8821-db8033d5.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cb28b9-08a22af7.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ccf2e8-59a6bfc9.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ccf2e8-ac055be6.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ccf2e8-f8c69860.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ce6f6d-50bbee62.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ce8219-12c6d905.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ce8219-d0b5582e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ce95b0-84be34a3.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cea101-06f21d5e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cea101-293a30b5.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cee0e0-5e25daa7.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cef86b-204ea619.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cef86b-d8d105b9.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cf8e3d-3d27efb0.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cf8e3d-4683d983.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cf8e3d-773de15e.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00cf8e3d-a7b4978c.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d0f034-6d666f7b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d15d58-9197cde5.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d18b13-52d3e4c4.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d1bafa-1b47b41c.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d1bafa-6701fcd9.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d4b6b7-7d0a60bf.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d4b6b7-a0b1a3e0.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d5edb9-f0077df3.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d7268f-fd4487be.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d77344-9fe25620.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d79c0a-23bea078.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d79c0a-a2b85ca4.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d84b1d-21e6fe01.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d8944b-e157478b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d8d95a-47d98291.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d8d95a-74aa476a.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d9e313-038310a2.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d9e313-7d75bb18.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00d9e313-926b6698.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00db9030-5102ed41.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00dc5030-237e7f71.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00de601c-858a8a8d.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00de601c-cfa2404b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e02d60-54df99d1.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e100a8-9c852617.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e100a8-a5e1ece9.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e11419-e4eeba84.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e42886-b826e91d.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e42886-bd5ed543.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e49ed1-9d41220c.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e4cae5-c0582574.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e5e793-22614772.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e5e793-f94de032.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e782b9-5fe9bffe.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e81dcc-b1dd9e7b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00e8c106-e197c4b1.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00eb41b2-6bbff2ca.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ecf963-bea6bf0f.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ed2e85-82bdd22b.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00ed2e85-95394dfd.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00edfec7-4d92adef.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f0dd0f-1adbde75.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f0dd0f-5e9c9557.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f28fce-a799f8a1.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f2b0d5-c84860fe.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f42f6b-5a20a4d2.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f42f6b-699a498c.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f42f6b-b1ca1f6c.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f7eac8-5193d600.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f89335-2ef7949d.xml
#   inflating: colab_frcnn-main/smallbdd/xml/00f8f875-bad0295f.xml

# %%
#pathの指定(colab_frcnn直下まで)
path='/content'
bdd_xml=path+"/colab_frcnn-main/smallbdd/xml"
bdd_img=path+"/colab_frcnn-main/smallbdd/img"
test_path=path+"/colab_frcnn-main/smallbdd/test"

#datasetのクラス指定
dataset_class=['person', 'traffic light', 'train', 'traffic sign', 'rider', 'car', 'bike', 'motor', 'truck', 'bus']
#表示したいラベルの色の指定
#注意！！一番最初は背景クラスを示すので(0,0,0)にする
colors = ((0,0,0),(255,0,0),(0,255,0),(0,0,255),(100,100,100),(50,50,50),(255,255,0),(255,0,255),(0,255,255),(100,100,0),(0,100,100))

#ハイパーパラメータの指定
epochs=10
batch_size=1
scale=720#画像のスケール設定(縦の大きさを入力)

# %% [markdown]
# ## 前準備(ドライブのマウント)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## ハイパーパラメータ、pathの指定

# %%
# #pathの指定(colab_frcnn直下まで)
# path='*****************'
# bdd_xml=path+"/colab_frcnn-main/smallbdd/xml"
# bdd_img=path+"/colab_frcnn-main/smallbdd/img"
# test_path=path+"/colab_frcnn-main/smallbdd/test"

# #datasetのクラス指定
# dataset_class=['person', 'traffic light', 'train', 'traffic sign', 'rider', 'car', 'bike', 'motor', 'truck', 'bus']
# #表示したいラベルの色の指定
# #注意！！一番最初は背景クラスを示すので(0,0,0)にする
# colors = ((0,0,0),(255,0,0),(0,255,0),(0,0,255),(100,100,100),(50,50,50),(255,255,0),(255,0,255),(0,255,255),(100,100,0),(0,100,100))

# #ハイパーパラメータの指定
# epochs=10
# batch_size=1
# scale=720#画像のスケール設定(縦の大きさを入力)

# %% [markdown]
# ## その1データの読み込み（dataloaderの作成）

# %%
import numpy as np
import pandas as pd
 
from PIL import Image
from glob import glob
import xml.etree.ElementTree as ET 
import cv2
 
import torch
import torchvision
from torchvision import transforms
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torch.utils.data import TensorDataset
import os


class xml2list(object):
    
    def __init__(self, classes):
        self.classes = classes
        
    def __call__(self, xml_path):
        
        ret = []
        xml = ET.parse(xml_path).getroot()
        
        boxes = []
        labels = []
        zz=0
        
        for zz,obj in enumerate(xml.iter('object')):
            
            label = obj.find('name').text
          
            ##指定クラスのみ

            if label in self.classes :
                bndbox = obj.find('bndbox')
                xmin = int(bndbox.find('xmin').text)
                ymin = int(bndbox.find('ymin').text)
                xmax = int(bndbox.find('xmax').text)
                ymax = int(bndbox.find('ymax').text)
                boxes.append([xmin, ymin, xmax, ymax])
                labels.append(self.classes.index(label))
            else:
                continue
            
        num_objs = zz +1

        anno = {'bboxes':boxes, 'labels':labels}

        return anno,num_objs

# %%
class MyDataset(torch.utils.data.Dataset):
    
        def __init__(self,image_dir,xml_paths,scale,classes):
            
            super().__init__()
            self.image_dir = image_dir
            self.xml_paths = xml_paths
            self.image_ids = sorted(glob('{}/*'.format(xml_paths)))
            self.scale=scale
            self.classes=classes
            
        def __getitem__(self, index):
    
            transform = transforms.Compose([
                                            transforms.ToTensor()
            ])
    
            # 入力画像の読み込み
            image_id=self.image_ids[index].split("/")[-1].split(".")[0]
            image = Image.open(f"{self.image_dir}/{image_id}.jpg")
            
            
            #画像のスケール変換
            t_scale_tate=self.scale ##目標のスケール(縦)
            #縮小比を計算
            ratio=t_scale_tate/image.size[1]
            ##目標横スケールを計算
            t_scale_yoko=image.size[0]*ratio
            t_scale_yoko=int(t_scale_yoko)
            
            #print('縮小前:',image.size)
            #print('縮小率:',ratio)
            #リサイズ
            image = image.resize((t_scale_yoko,t_scale_tate))
            #print('縮小後:',image.size)
  
            image = transform(image)
        
            transform_anno = xml2list(self.classes)
            path_xml=f'{self.xml_paths}/{image_id}.xml'
            

            annotations,obje_num= transform_anno(path_xml)

            boxes = torch.as_tensor(annotations['bboxes'], dtype=torch.int64)
            labels = torch.as_tensor(annotations['labels'], dtype=torch.int64)

          
            #bboxの縮小
            #print('縮小前:',boxes)
            boxes=boxes*ratio
            #print('縮小後:',boxes)
        
            area = (boxes[:, 3]-boxes[:, 1]) * (boxes[:, 2]-boxes[:, 0])
            area = torch.as_tensor(area, dtype=torch.float32)

            iscrowd = torch.zeros((obje_num,), dtype=torch.int64)

            target = {}
            target["boxes"] = boxes
            target["labels"] = labels+1
            target["image_id"] = torch.tensor([index])
            target["area"] = area
            target["iscrowd"] = iscrowd
            return image, target,image_id
        
        def __len__(self):

            return len(self.image_ids)

# %%
def dataloader (data,dataset_class,batch_size,scale=720):
    xml_paths=data[0]
    image_dir1=data[1]
    dataset = MyDataset(image_dir1,xml_paths,scale,dataset_class)

    #データのロード
    torch.manual_seed(2020)
    def collate_fn(batch):
        return tuple(zip(*batch))

    train_dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True,collate_fn=collate_fn)
    

    return train_dataloader

# %% [markdown]
# # modelの定義

# %%
def model ():
    #モデルの定義
    
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    num_classes=len(dataset_class)+1
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# %% [markdown]
# # train

# %%
data_ALL=[bdd_xml,bdd_img]
train_dataloader=dataloader(data_ALL,dataset_class,batch_size,scale)

model=model()
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
num_epochs = epochs



device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu') 

model.cuda()

model.train()#学習モードに移行

loss_list=[]
for epoch in range(num_epochs):
    loss_epo=[]
 
    #model.train()#これから学習しますよ
    
    for i, batch in enumerate(train_dataloader):
        
 
        images, targets, image_ids = batch#####　batchはそのミニバッジのimage、tagets,image_idsが入ってる
        
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        
        ##学習モードでは画像とターゲット（ground-truth）を入力する
        ##返り値はdict[tensor]でlossが入ってる。（RPNとRCNN両方のloss）
        loss_dict= model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()
        
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        #lossの保存
        loss_epo.append(loss_value)
 
        if (i+1) % 10== 0:
          print(f"epoch #{epoch+1} Iteration #{i+1} loss: {loss_value}") 
          
        
    #Epochごとのlossの保存
    loss_list.append(np.mean(loss_epo))
    torch.save(model, path+'/colab_frcnn-main/model.pt')
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
#   0%|          | 0.00/160M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# epoch #1 Iteration #10 loss: 2.18843674659729
# epoch #1 Iteration #20 loss: 1.75957190990448
# epoch #1 Iteration #30 loss: 1.6731736660003662
# epoch #1 Iteration #40 loss: 1.6991808414459229
# epoch #1 Iteration #50 loss: 1.3284209966659546
# epoch #1 Iteration #60 loss: 1.8520166873931885
# epoch #1 Iteration #70 loss: 1.7336411476135254
# epoch #1 Iteration #80 loss: 1.000614881515503
# epoch #1 Iteration #90 loss: 1.4171361923217773
# epoch #1 Iteration #100 loss: 0.7611759901046753
# epoch #1 Iteration #110 loss: 1.5505784749984741
# epoch #1 Iteration #120 loss: 1.0356054306030273
# epoch #2 Iteration #10 loss: 1.826207160949707
# epoch #2 Iteration #20 loss: 1.752608299255371
# epoch #2 Iteration #30 loss: 1.033703088760376
# epoch #2 Iteration #40 loss: 1.239704966545105
# epoch #2 Iteration #50 loss: 1.499306321144104
# epoch #2 Iteration #60 loss: 1.4870190620422363
# epoch #2 Iteration #70 loss: 1.0029551982879639
# epoch #2 Iteration #80 loss: 1.31632661819458
# epoch #2 Iteration #90 loss: 1.6351540088653564
# epoch #2 Iteration #100 loss: 1.4641528129577637
# epoch #2 Iteration #110 loss: 1.1057610511779785
# epoch #2 Iteration #120 loss: 0.9843389391899109
# epoch #3 Iteration #10 loss: 1.2334903478622437
# epoch #3 Iteration #20 loss: 1.0907727479934692
# epoch #3 Iteration #30 loss: 1.4608049392700195
# epoch #3 Iteration #40 loss: 1.041952133178711
# epoch #3 Iteration #50 loss: 1.496893286705017
# epoch #3 Iteration #60 loss: 1.100225567817688
# epoch #3 Iteration #70 loss: 0.9523109197616577
# epoch #3 Iteration #80 loss: 1.2197449207305908
# epoch #3 Iteration #90 loss: 1.1976617574691772
# epoch #3 Iteration #100 loss: 1.5659451484680176
# epoch #3 Iteration #110 loss: 1.1217728853225708
# epoch #3 Iteration #120 loss: 1.054370641708374
# epoch #4 Iteration #10 loss: 0.40441545844078064
# epoch #4 Iteration #20 loss: 1.079120397567749
# epoch #4 Iteration #30 loss: 1.0418671369552612
# epoch #4 Iteration #40 loss: 0.9072479009628296
# epoch #4 Iteration #50 loss: 1.2648855447769165
# epoch #4 Iteration #60 loss: 1.0426973104476929
# epoch #4 Iteration #70 loss: 0.7592679262161255
# epoch #4 Iteration #80 loss: 0.9106395840644836
# epoch #4 Iteration #90 loss: 0.8659390211105347
# epoch #4 Iteration #100 loss: 1.4105801582336426
# epoch #4 Iteration #110 loss: 1.3077635765075684
# epoch #4 Iteration #120 loss: 0.8701121211051941
# epoch #5 Iteration #10 loss: 0.571241557598114
# epoch #5 Iteration #20 loss: 0.7898268699645996
# epoch #5 Iteration #30 loss: 0.9847077131271362
# epoch #5 Iteration #40 loss: 0.8017785549163818
# epoch #5 Iteration #50 loss: 0.7929321527481079
# epoch #5 Iteration #60 loss: 1.08304762840271
# epoch #5 Iteration #70 loss: 0.6360960006713867
# epoch #5 Iteration #80 loss: 1.0079593658447266
# epoch #5 Iteration #90 loss: 0.9569447040557861
# epoch #5 Iteration #100 loss: 0.663561224937439
# epoch #5 Iteration #110 loss: 0.9480568170547485
# epoch #5 Iteration #120 loss: 0.826842725276947
# epoch #6 Iteration #10 loss: 0.8653731346130371
# epoch #6 Iteration #20 loss: 0.8295493125915527
# epoch #6 Iteration #30 loss: 0.7770184874534607
# epoch #6 Iteration #40 loss: 0.7755991220474243
# epoch #6 Iteration #50 loss: 0.6148741245269775
# epoch #6 Iteration #60 loss: 0.6749715805053711
# epoch #6 Iteration #70 loss: 0.601527988910675
# epoch #6 Iteration #80 loss: 0.9734401702880859
# epoch #6 Iteration #90 loss: 0.8476763367652893
# epoch #6 Iteration #100 loss: 0.7299283742904663
# epoch #6 Iteration #110 loss: 0.7597358226776123
# epoch #6 Iteration #120 loss: 1.2610867023468018
# epoch #7 Iteration #10 loss: 0.5921565294265747
# epoch #7 Iteration #20 loss: 0.9886423349380493
# epoch #7 Iteration #30 loss: 0.2227439433336258
# epoch #7 Iteration #40 loss: 0.8964254856109619
# epoch #7 Iteration #50 loss: 0.6609199643135071
# epoch #7 Iteration #60 loss: 0.8836468458175659
# epoch #7 Iteration #70 loss: 1.0311275720596313
# epoch #7 Iteration #80 loss: 0.663411021232605
# epoch #7 Iteration #90 loss: 0.6650307178497314
# epoch #7 Iteration #100 loss: 0.710761308670044
# epoch #7 Iteration #110 loss: 0.9943767786026001
# epoch #7 Iteration #120 loss: 0.6766650676727295
# epoch #8 Iteration #10 loss: 0.8541566729545593
# epoch #8 Iteration #20 loss: 0.9130842089653015
# epoch #8 Iteration #30 loss: 0.39950281381607056
# epoch #8 Iteration #40 loss: 0.7182332873344421
# epoch #8 Iteration #50 loss: 0.6852530837059021
# epoch #8 Iteration #60 loss: 0.596075177192688
# epoch #8 Iteration #70 loss: 0.14933191239833832
# epoch #8 Iteration #80 loss: 0.6360651850700378
# epoch #8 Iteration #90 loss: 0.7096196413040161
# epoch #8 Iteration #100 loss: 0.6442717909812927
# epoch #8 Iteration #110 loss: 0.6123316287994385
# epoch #8 Iteration #120 loss: 0.5212892889976501
# epoch #9 Iteration #10 loss: 0.6212872862815857
# epoch #9 Iteration #20 loss: 1.1439332962036133
# epoch #9 Iteration #30 loss: 0.6401292085647583
# epoch #9 Iteration #40 loss: 0.6282774806022644
# epoch #9 Iteration #50 loss: 0.34318628907203674
# epoch #9 Iteration #60 loss: 0.440583199262619
# epoch #9 Iteration #70 loss: 0.45748579502105713
# epoch #9 Iteration #80 loss: 0.17279300093650818
# epoch #9 Iteration #90 loss: 0.35604602098464966
# epoch #9 Iteration #100 loss: 0.6412180662155151
# epoch #9 Iteration #110 loss: 0.8545050024986267
# epoch #9 Iteration #120 loss: 0.678343653678894
# epoch #10 Iteration #10 loss: 0.732177734375
# epoch #10 Iteration #20 loss: 0.7669403553009033
# epoch #10 Iteration #30 loss: 0.5158514976501465
# epoch #10 Iteration #40 loss: 0.3574131727218628
# epoch #10 Iteration #50 loss: 0.6373240947723389
# epoch #10 Iteration #60 loss: 0.2584872245788574
# epoch #10 Iteration #70 loss: 1.0543386936187744
# epoch #10 Iteration #80 loss: 0.9158614873886108
# epoch #10 Iteration #90 loss: 0.8505389094352722
# epoch #10 Iteration #100 loss: 0.5024483799934387
# epoch #10 Iteration #110 loss: 0.5373075008392334
# epoch #10 Iteration #120 loss: 0.3300933241844177

# %% [markdown]
# # Test
# 学習結果をもとに結果をテスト

# %%
import cv2
import glob
import matplotlib.pyplot as plt

data_class=dataset_class
data_class.insert(0, "__background__")
classes = tuple(data_class)

#学習済みモデルで推論する場合
#model=torch.load(path+'/colab_frcnn/model.pt')

# %%
model.to(device)

model.eval()
for imgfile in sorted(glob.glob(test_path+'/*')):
    
    img = cv2.imread(imgfile)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    image_tensor = torchvision.transforms.functional.to_tensor(img)

    with torch.no_grad():
        prediction = model([image_tensor.to(device)])
    
    for i,box in enumerate(prediction[0]['boxes']):
        score = prediction[0]['scores'][i].cpu().numpy()
        if score > 0.5:
            score = round(float(score),2)
            cat = prediction[0]['labels'][i].cpu().numpy()
            txt = '{} {}'.format(classes[int(cat)], str(score))
            font = cv2.FONT_HERSHEY_SIMPLEX
            cat_size = cv2.getTextSize(txt, font, 0.5, 2)[0]
            c = colors[int(cat)]
            box=box.cpu().numpy().astype('int')
            cv2.rectangle(img, (box[0], box[1]), (box[2], box[3]), c , 2)
            cv2.rectangle(img,(box[0], box[1] - cat_size[1] - 2),(box[0] + cat_size[0], box[1] - 2), c, -1)
            cv2.putText(img, txt, (box[0], box[1] - 2), font, 0.5, (0, 0, 0), thickness=1, lineType=cv2.LINE_AA)


    plt.figure(figsize=(15,10))
    plt.imshow(img)
plt.show()
